# %%
import numpy as np 
import pandas as pd

# %%
import warnings
warnings.filterwarnings('ignore')
# read file
voice=pd.read_csv('C:\\Users\\Aditya Ram\\Downloads\\archive.zip')
voice.head()
# Out:
#    meanfreq        sd    median       Q25       Q75       IQR       skew  \
# 0  0.059781  0.064241  0.032027  0.015071  0.090193  0.075122  12.863462
# 1  0.066009  0.067310  0.040229  0.019414  0.092666  0.073252  22.423285
# 2  0.077316  0.083829  0.036718  0.008701  0.131908  0.123207  30.757155
# 3  0.151228  0.072111  0.158011  0.096582  0.207955  0.111374   1.232831
# 4  0.135120  0.079146  0.124656  0.078720  0.206045  0.127325   1.101174
#
#           kurt    sp.ent       sfm  ...  centroid   meanfun    minfun  \
# 0   274.402906  0.893369  0.491918  ...  0.059781  0.084279  0.015702
# 1   634.613855  0.892193  0.513724  ...  0.066009  0.107937  0.015826
# 2  1024.927705  0.846389  0.478905  ...  0.077316  0.098706  0.015656
# 3     4.177296  0.963322  0.727232  ...  0.151228  0.088965  0.017798
# 4     4.333713  0.971955  0.783568  ...  0.135120  0.106398  0.016931
#
#      maxfun   meandom    mindom    maxdom   dfrange   modindx  label
# 0  0.275862  0.007812  0.007812  0.007812  0.000000  0.000000   male
# 1  0.250000  0.009014  0.007812  0.054688  0.046875  0.052632   male
# 2  0.271186  0.007990  0.007812  0.015625  0.007812  0.046512   male
# 3  0.250000  0.201497  0.007812  0.562500  0.554688  0.247119   male
# 4  0.266667  0.712812  0.007812  5.484375  5.476562  0.208274   male
#
# [5 rows x 21 columns]

# %%
voice.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3168 entries, 0 to 3167
# Data columns (total 21 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   meanfreq  3168 non-null   float64
#  1   sd        3168 non-null   float64
#  2   median    3168 non-null   float64
#  3   Q25       3168 non-null   float64
#  4   Q75       3168 non-null   float64
#  5   IQR       3168 non-null   float64
#  6   skew      3168 non-null   float64
#  7   kurt      3168 non-null   float64
#  8   sp.ent    3168 non-null   float64
#  9   sfm       3168 non-null   float64
#  10  mode      3168 non-null   float64
#  11  centroid  3168 non-null   float64
#  12  meanfun   3168 non-null   float64
#  13  minfun    3168 non-null   float64
#  14  maxfun    3168 non-null   float64
#  15  meandom   3168 non-null   float64
#  16  mindom    3168 non-null   float64
#  17  maxdom    3168 non-null   float64
#  18  dfrange   3168 non-null   float64
#  19  modindx   3168 non-null   float64
#  20  label     3168 non-null   object
# dtypes: float64(20), object(1)
# memory usage: 519.9+ KB

# %%
voice.describe()
# Out:
#           meanfreq           sd       median          Q25          Q75  \
# count  3168.000000  3168.000000  3168.000000  3168.000000  3168.000000
# mean      0.180907     0.057126     0.185621     0.140456     0.224765
# std       0.029918     0.016652     0.036360     0.048680     0.023639
# min       0.039363     0.018363     0.010975     0.000229     0.042946
# 25%       0.163662     0.041954     0.169593     0.111087     0.208747
# 50%       0.184838     0.059155     0.190032     0.140286     0.225684
# 75%       0.199146     0.067020     0.210618     0.175939     0.243660
# max       0.251124     0.115273     0.261224     0.247347     0.273469
#
#                IQR         skew         kurt       sp.ent          sfm  \
# count  3168.000000  3168.000000  3168.000000  3168.000000  3168.000000
# mean      0.084309     3.140168    36.568461     0.895127     0.408216
# std       0.042783     4.240529   134.928661     0.044980     0.177521
# min       0.014558     0.141735     2.068455     0.738651     0.036876
# 25%       0.042560     1.649569     5.669547     0.861811     0.258041
# 50%       0.094280     2.197101     8.318463     0.901767     0.396335
# 75%       0.114175     2.931694    13.648905     0.928713     0.533676
# max       0.252225    34.725453  1309.612887     0.981997     0.842936
#
#               mode     centroid      meanfun       minfun       maxfun  \
# count  3168.000000  3168.000000  3168.000000  3168.000000  3168.000000
# mean      0.165282     0.180907     0.142807     0.036802     0.258842
# std       0.077203     0.029918     0.032304     0.019220     0.030077
# min       0.000000     0.039363     0.055565     0.009775     0.103093
# 25%       0.118016     0.163662     0.116998     0.018223     0.253968
# 50%       0.186599     0.184838     0.140519     0.046110     0.271186
# 75%       0.221104     0.199146     0.169581     0.047904     0.277457
# max       0.280000     0.251124     0.237636     0.204082     0.279114
#
#            meandom       mindom       maxdom      dfrange      modindx
# count  3168.000000  3168.000000  3168.000000  3168.000000  3168.000000
# mean      0.829211     0.052647     5.047277     4.994630     0.173752
# std       0.525205     0.063299     3.521157     3.520039     0.119454
# min       0.007812     0.004883     0.007812     0.000000     0.000000
# 25%       0.419828     0.007812     2.070312     2.044922     0.099766
# 50%       0.765795     0.023438     4.992188     4.945312     0.139357
# 75%       1.177166     0.070312     7.007812     6.992188     0.209183
# max       2.957682     0.458984    21.867188    21.843750     0.932374

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
voice["label"] = le.fit_transform(voice["label"])
le.classes_
# Out:
# array(['female', 'male'], dtype=object)

# %%
voice[:]=preprocessing.MinMaxScaler().fit_transform(voice)
voice.head()
# Out:
#    meanfreq        sd    median       Q25       Q75       IQR      skew  \
# 0  0.096419  0.473409  0.084125  0.060063  0.204956  0.254828  0.367853
# 1  0.125828  0.505075  0.116900  0.077635  0.215683  0.246961  0.644279
# 2  0.179222  0.675536  0.102873  0.034284  0.385912  0.457148  0.885255
# 3  0.528261  0.554611  0.587559  0.389906  0.715802  0.407358  0.031549
# 4  0.452195  0.627209  0.454272  0.317627  0.707515  0.474474  0.027742
#
#        kurt    sp.ent       sfm  ...  centroid   meanfun    minfun    maxfun  \
# 0  0.208279  0.635798  0.564526  ...  0.096419  0.157706  0.030501  0.981526
# 1  0.483766  0.630964  0.591578  ...  0.125828  0.287642  0.031140  0.834600
# 2  0.782275  0.442738  0.548382  ...  0.179222  0.236945  0.030264  0.954963
# 3  0.001613  0.923261  0.856457  ...  0.528261  0.183442  0.041287  0.834600
# 4  0.001732  0.958736  0.926348  ...  0.452195  0.279190  0.036829  0.929285
#
#     meandom    mindom    maxdom   dfrange   modindx  label
# 0  0.000000  0.006452  0.000000  0.000000  0.000000    1.0
# 1  0.000407  0.006452  0.002144  0.002146  0.056449    1.0
# 2  0.000060  0.006452  0.000357  0.000358  0.049885    1.0
# 3  0.065659  0.006452  0.025375  0.025393  0.265043    1.0
# 4  0.238994  0.006452  0.250536  0.250715  0.223380    1.0
#
# [5 rows x 21 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.subplots(4,5,figsize=(15,15))
for i in range(1,21):
    plt.subplot(4,5,i)
    plt.title(voice.columns[i-1])
    sns.kdeplot(voice.loc[voice['label'] == 0, voice.columns[i-1]], color= 'green', label='F')
    sns.kdeplot(voice.loc[voice['label'] == 1, voice.columns[i-1]], color= 'blue', label='M')

# %%
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

from sklearn import neighbors
from sklearn import naive_bayes
from sklearn import tree
from sklearn import ensemble
from sklearn import svm
from sklearn import neural_network
import xgboost

# %%
train, test = train_test_split(voice, test_size=0.3)

# %%
train.head()
# Out:
#       meanfreq        sd    median       Q25       Q75       IQR      skew  \
# 350   0.531134  0.446883  0.504223  0.409809  0.696204  0.367656  0.083973
# 2747  0.686933  0.191054  0.678689  0.664706  0.691916  0.098463  0.084414
# 2937  0.556297  0.511712  0.632904  0.517494  0.707305  0.266456  0.101994
# 892   0.692157  0.457724  0.672840  0.570430  0.842100  0.342157  0.034312
# 2156  0.709312  0.203626  0.718317  0.720332  0.710796  0.058938  0.081594
#
#           kurt    sp.ent       sfm  ...  centroid   meanfun    minfun  \
# 350   0.009175  0.690586  0.549942  ...  0.531134  0.246070  0.050210
# 2747  0.009758  0.476382  0.295741  ...  0.686933  0.641892  0.198968
# 2937  0.026503  0.833296  0.733356  ...  0.556297  0.562847  0.030422
# 892   0.001682  0.762818  0.572299  ...  0.692157  0.399300  0.197717
# 2156  0.008228  0.484180  0.345049  ...  0.709312  0.646633  0.039294
#
#         maxfun   meandom    mindom    maxdom   dfrange   modindx  label
# 350   0.834600  0.328179  0.225806  0.180799  0.176368  0.305661    1.0
# 2747  0.981526  0.237655  0.040860  0.261258  0.260730  0.081553    0.0
# 2937  0.981526  0.018980  0.006452  0.009650  0.009657  0.160365    0.0
# 892   0.990585  0.176309  0.040860  0.172266  0.171674  0.086085    1.0
# 2156  0.954963  0.298499  0.384946  0.221587  0.213877  0.206958    0.0
#
# [5 rows x 21 columns]

# %%
x_train = train.iloc[:, :-1]
y_train = train["label"]
x_test = test.iloc[:, :-1]
y_test = test["label"]

# %%
x_train3 = train[["meanfun","IQR","Q25"]]
y_train3 = train["label"]
x_test3 = test[["meanfun","IQR","Q25"]]
y_test3 = test["label"]

# %%
def classify(model,x_train,y_train,x_test,y_test):
    from sklearn.metrics import classification_report
    target_names = ['female', 'male']
    model.fit(x_train,y_train)
    y_pred=model.predict(x_test)
    print(classification_report(y_test, y_pred, target_names=target_names, digits=4))

# %%
def knn_error(k,x_train,y_train,x_test,y_test):
    error_rate = []
    K=range(1,k)
    for i in K:
        knn = neighbors.KNeighborsClassifier(n_neighbors = i)
        knn.fit(x_train, y_train)
        y_pred = knn.predict(x_test)
        error_rate.append(np.mean(y_pred != y_test))
    kloc = error_rate.index(min(error_rate))
    print("Lowest error is %s occurs at k=%s." % (error_rate[kloc], K[kloc]))

    plt.plot(K, error_rate, color='blue', linestyle='dashed', marker='o',
             markerfacecolor='red', markersize=10)
    plt.title('Error Rate vs. K Value')
    plt.xlabel('K')
    plt.ylabel('Error Rate')
    plt.show()
    return K[kloc]

# %%
k=knn_error(21,x_train,y_train,x_test,y_test)
# Out:
# Lowest error is 0.022082018927444796 occurs at k=1.

# %%
model = neighbors.KNeighborsClassifier(n_neighbors = k)
classify(model,x_train,y_train,x_test,y_test)
# Out:
#               precision    recall  f1-score   support
#
#       female     0.9783    0.9761    0.9772       461
#         male     0.9776    0.9796    0.9786       490
#
#     accuracy                         0.9779       951
#    macro avg     0.9779    0.9779    0.9779       951
# weighted avg     0.9779    0.9779    0.9779       951

# %%
k=knn_error(21,x_train3,y_train3,x_test3,y_test3)
# Out:
# Lowest error is 0.027339642481598318 occurs at k=7.

# %%
model = neighbors.KNeighborsClassifier(n_neighbors = k)
classify(model,x_train,y_train,x_test,y_test)
# Out:
#               precision    recall  f1-score   support
#
#       female     0.9759    0.9675    0.9717       461
#         male     0.9696    0.9776    0.9736       490
#
#     accuracy                         0.9727       951
#    macro avg     0.9728    0.9725    0.9726       951
# weighted avg     0.9727    0.9727    0.9727       951

# %%
model=naive_bayes.GaussianNB()
classify(model,x_train,y_train,x_test,y_test)
# Out:
#               precision    recall  f1-score   support
#
#       female     0.9279    0.8937    0.9105       461
#         male     0.9034    0.9347    0.9188       490
#
#     accuracy                         0.9148       951
#    macro avg     0.9156    0.9142    0.9146       951
# weighted avg     0.9153    0.9148    0.9148       951

# %%
model=naive_bayes.GaussianNB()
classify(model,x_train3,y_train3,x_test3,y_test3)
# Out:
#               precision    recall  f1-score   support
#
#       female     0.9713    0.9544    0.9628       461
#         male     0.9578    0.9735    0.9656       490
#
#     accuracy                         0.9642       951
#    macro avg     0.9646    0.9640    0.9642       951
# weighted avg     0.9644    0.9642    0.9642       951

# %%
def dt_error(n,x_train,y_train,x_test,y_test):
    nodes = range(2, n)
    error_rate = []
    for k in nodes:
        model = tree.DecisionTreeClassifier(max_leaf_nodes=k)
        model.fit(x_train, y_train)
        y_pred = model.predict(x_test)
        error_rate.append(np.mean(y_pred != y_test))
    kloc = error_rate.index(min(error_rate))
    print("Lowest error is %s occurs at n=%s." % (error_rate[kloc], nodes[kloc]))
    plt.plot(nodes, error_rate, color='blue', linestyle='dashed', marker='o',
             markerfacecolor='red', markersize=10)
    plt.xlabel('Tree Size')
    plt.ylabel('Cross-Validated MSE')
    plt.show()
    return nodes[kloc]

# %%
n=dt_error(10,x_train,y_train,x_test,y_test)
# Out:
# Lowest error is 0.03259726603575184 occurs at n=9.

# %%
pruned_tree = tree.DecisionTreeClassifier(criterion = 'gini', max_leaf_nodes = n)
classify(pruned_tree,x_train,y_train,x_test,y_test)
# Out:
#               precision    recall  f1-score   support
#
#       female     0.9778    0.9544    0.9660       461
#         male     0.9581    0.9796    0.9687       490
#
#     accuracy                         0.9674       951
#    macro avg     0.9679    0.9670    0.9673       951
# weighted avg     0.9676    0.9674    0.9674       951

# %%
n=dt_error(15,x_train3,y_train3,x_test3,y_test3)
# Out:
# Lowest error is 0.035751840168243953 occurs at n=11.

# %%
pruned_tree = tree.DecisionTreeClassifier(criterion = 'gini', max_leaf_nodes = n)
classify(pruned_tree,x_train3,y_train3,x_test3,y_test3)
# Out:
#               precision    recall  f1-score   support
#
#       female     0.9734    0.9523    0.9627       461
#         male     0.9560    0.9755    0.9657       490
#
#     accuracy                         0.9642       951
#    macro avg     0.9647    0.9639    0.9642       951
# weighted avg     0.9644    0.9642    0.9642       951

# %%
def rf_error(n,x_train,y_train,x_test,y_test):
    error_rate = []
    e=range(1,n,20)
    for i in e:
        model = ensemble.RandomForestClassifier(n_estimators = i)
        model.fit(x_train, y_train)
        y_pred = model.predict(x_test)
        error_rate.append(np.mean(y_pred != y_test))
    nloc = error_rate.index(min(error_rate))
    print("Lowest error is %s occurs at n=%s." % (error_rate[nloc], e[nloc]))

    plt.plot(e, error_rate, color='blue', linestyle='dashed', marker='o',
             markerfacecolor='red', markersize=10)
    plt.title('Error Rate vs. n Value')
    plt.xlabel('n')
    plt.ylabel('Error Rate')
    plt.show()
    return e[nloc]

# %%
e=rf_error(100,x_train,y_train,x_test,y_test)
# Out:
# Lowest error is 0.022082018927444796 occurs at n=61.

# %%
model=ensemble.RandomForestClassifier(n_estimators = e)
classify(model,x_train,y_train,x_test,y_test)
# Out:
#               precision    recall  f1-score   support
#
#       female     0.9802    0.9675    0.9738       461
#         male     0.9698    0.9816    0.9757       490
#
#     accuracy                         0.9748       951
#    macro avg     0.9750    0.9745    0.9747       951
# weighted avg     0.9748    0.9748    0.9748       951

# %%
e=rf_error(100,x_train3,y_train3,x_test3,y_test3)
# Out:
# Lowest error is 0.027339642481598318 occurs at n=41.

# %%
model=ensemble.RandomForestClassifier(n_estimators = e)
classify(model,x_train3,y_train3,x_test3,y_test3)
# Out:
#               precision    recall  f1-score   support
#
#       female     0.9738    0.9675    0.9706       461
#         male     0.9696    0.9755    0.9725       490
#
#     accuracy                         0.9716       951
#    macro avg     0.9717    0.9715    0.9716       951
# weighted avg     0.9716    0.9716    0.9716       951

# %%
model = xgboost.XGBClassifier()
classify(model,x_train,y_train,x_test,y_test)
# Out:
#               precision    recall  f1-score   support
#
#       female     0.9784    0.9826    0.9805       461
#         male     0.9836    0.9796    0.9816       490
#
#     accuracy                         0.9811       951
#    macro avg     0.9810    0.9811    0.9811       951
# weighted avg     0.9811    0.9811    0.9811       951

# %%
model = xgboost.XGBClassifier()
classify(model,x_train3,y_train3,x_test3,y_test3)
# Out:
#               precision    recall  f1-score   support
#
#       female     0.9736    0.9588    0.9661       461
#         male     0.9618    0.9755    0.9686       490
#
#     accuracy                         0.9674       951
#    macro avg     0.9677    0.9671    0.9674       951
# weighted avg     0.9675    0.9674    0.9674       951

# %%
def svm_kernel(x_train,y_train,x_test,y_test):
    rate=[]
    kernel=['rbf','poly','linear']
    for i in kernel:
        model=svm.SVC(kernel=i).fit(x_train,y_train)
        y_pred=model.predict(x_train)
        print(i, ' in-sample accuracy in SVM: ', accuracy_score(y_train,y_pred))
        y_pred=model.predict(x_test)
        print(i, ' out-of-sample accuracy in SVM: ', accuracy_score(y_test,y_pred))
        rate.append(accuracy_score(y_test,y_pred))
    nloc = rate.index(max(rate))
    print("Highest accuracy is %s occurs at %s kernel." % (rate[nloc], kernel[nloc]))
    return kernel[nloc]

# %%
def svm_error(k,C,x_train,y_train,x_test,y_test):
    error_rate = []
    C=range(1,C)
    for i in C:
        model=svm.SVC(kernel=k,C=i).fit(x_train,y_train)
        model.fit(x_train, y_train)
        y_pred = model.predict(x_test)
        error_rate.append(np.mean(y_pred != y_test))
    cloc = error_rate.index(min(error_rate))
    print("Lowest error is %s occurs at C=%s." % (error_rate[cloc], C[cloc]))

    plt.plot(C, error_rate, color='blue', linestyle='dashed', marker='o',
             markerfacecolor='red', markersize=10)
    plt.title('Error Rate vs. C Value')
    plt.xlabel('C')
    plt.ylabel('Error Rate')
    plt.show()
    return C[cloc]

# %%
k=svm_kernel(x_train,y_train,x_test,y_test)
# Out:
# rbf  in-sample accuracy in SVM:  0.9788001804239964
# rbf  out-of-sample accuracy in SVM:  0.9779179810725552
# poly  in-sample accuracy in SVM:  0.9806044203879116
# poly  out-of-sample accuracy in SVM:  0.9810725552050473
# linear  in-sample accuracy in SVM:  0.9733874605322508
# linear  out-of-sample accuracy in SVM:  0.9737118822292324
# Highest accuracy is 0.9810725552050473 occurs at poly kernel.

# %%
c=svm_error(k,10,x_train,y_train,x_test,y_test)
# Out:
# Lowest error is 0.016824395373291272 occurs at C=8.

# %%
model=svm.SVC(kernel=k,C=c)
classify(model,x_train,y_train,x_test,y_test)
# Out:
#               precision    recall  f1-score   support
#
#       female     0.9806    0.9848    0.9827       461
#         male     0.9857    0.9816    0.9836       490
#
#     accuracy                         0.9832       951
#    macro avg     0.9831    0.9832    0.9832       951
# weighted avg     0.9832    0.9832    0.9832       951

# %%
k=svm_kernel(x_train3,y_train3,x_test3,y_test3)
# Out:
# rbf  in-sample accuracy in SVM:  0.9742895805142084
# rbf  out-of-sample accuracy in SVM:  0.9695057833859095
# poly  in-sample accuracy in SVM:  0.9702300405953992
# poly  out-of-sample accuracy in SVM:  0.9695057833859095
# linear  in-sample accuracy in SVM:  0.9666215606675688
# linear  out-of-sample accuracy in SVM:  0.9652996845425867
# Highest accuracy is 0.9695057833859095 occurs at rbf kernel.

# %%
c=svm_error(k,10,x_train3,y_train3,x_test3,y_test3)
# Out:
# Lowest error is 0.025236593059936908 occurs at C=5.

# %%
model=svm.SVC(kernel=k,C=c)
classify(model,x_train3,y_train3,x_test3,y_test3)
# Out:
#               precision    recall  f1-score   support
#
#       female     0.9802    0.9675    0.9738       461
#         male     0.9698    0.9816    0.9757       490
#
#     accuracy                         0.9748       951
#    macro avg     0.9750    0.9745    0.9747       951
# weighted avg     0.9748    0.9748    0.9748       951

# %%
def nn_error(n,x_train,y_train,x_test,y_test):
    error_rate = []
    hidden_layer=range(1,n)
    for i in hidden_layer:
        model = neural_network.MLPClassifier(solver='adam', alpha=1e-5,
                                       hidden_layer_sizes=i,
                                       activation='logistic',random_state=17,
                                       max_iter=2000)
        model.fit(x_train, y_train)
        y_pred = model.predict(x_test)
        error_rate.append(np.mean(y_pred != y_test))
    kloc = error_rate.index(min(error_rate))
    print("Lowest error is %s occurs at C=%s." % (error_rate[kloc], hidden_layer[kloc]))

    plt.plot(hidden_layer, error_rate, color='blue', linestyle='dashed', marker='o',
             markerfacecolor='red', markersize=10)
    plt.title('Error Rate vs. Hidden Layer Size')
    plt.xlabel('Size')
    plt.ylabel('Error Rate')
    plt.show()
    return hidden_layer[kloc]

# %%
h=nn_error(20,x_train,y_train,x_test,y_test)
# Out:
# Lowest error is 0.026288117770767613 occurs at C=14.

# %%
model = neural_network.MLPClassifier(solver='adam', alpha=1e-5,
                                       hidden_layer_sizes=h,
                                       activation='logistic',random_state=17,
                                       max_iter=2000)
classify(model,x_train,y_train,x_test,y_test)
# Out:
#               precision    recall  f1-score   support
#
#       female     0.9781    0.9675    0.9727       461
#         male     0.9697    0.9796    0.9746       490
#
#     accuracy                         0.9737       951
#    macro avg     0.9739    0.9735    0.9737       951
# weighted avg     0.9738    0.9737    0.9737       951

# %%
h=nn_error(20,x_train3,y_train3,x_test3,y_test3)
# Out:
# Lowest error is 0.031545741324921134 occurs at C=1.

# %%
model = neural_network.MLPClassifier(solver='adam', alpha=1e-5,
                                       hidden_layer_sizes=h,
                                       activation='logistic',random_state=17,
                                       max_iter=2000)
classify(model,x_train3,y_train3,x_test3,y_test3)
# Out:
#               precision    recall  f1-score   support
#
#       female     0.9757    0.9588    0.9672       461
#         male     0.9618    0.9776    0.9696       490
#
#     accuracy                         0.9685       951
#    macro avg     0.9688    0.9682    0.9684       951
# weighted avg     0.9686    0.9685    0.9684       951

# %% [markdown]
# We can see that the highest accurracy is 98.1% which is made by XgBoost. XgBoost is a powerful algorithm, and very popular in Data Science competition. Next time I will try to oppotimize the parameters of XgBoost.
